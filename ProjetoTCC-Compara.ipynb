# %% [markdown]
# ### 1. Definição do problema <br>
# #### 1.1 Contextualização <br>
# <p> O ano de 2020 marcou o início da pandemia de COVID-19, causada pelo coronavírus (SARS-CoV-2)
# <br><br> É patente que a pandemia produz repercussões de ordem biomédica e epidemiológica em escala global. No entanto, também há fortes repercussões e impactos nas áreas social, econômica, política, ambiental e outras, sem precedentes na história recente das epidemias.
# <br><br> Segundo a Organização para a Cooperação e Desenvolvimento Econômico (OCDE), em razão do surto de coronavírus, a economia global pode crescer na taxa mais baixa desde 2009.
# <br><br> Uma das áreas da economia que sofreu forte impacto é o comércio exterior, em função da redução da atividade econômica em escala global.
# <br><br> O Brasil, como todo país inserido numa economia globalizada, também foi atingido pelos efeitos da economia, principalmente por ter a China como principal parceiro econômico.
# </p>
#
# #### 1.2 O problema proposto <br>
#  O objetivo deste trabalho é apresentar uma análise sobre as importações nos anos de 2019 (antes da pandemia) e 2020 (durante a pandemia) e projetar o resultado dessa atividade para 2021. <br>
# > Why? <br>
# >>  Uma das áreas da economia que sofreu forte impacto da pandemia de COVID-19 foi o comércio exterior, em função da redução da atividade econômica em escala global. A importação de mercadorias é importante indicador do estado da atividade econômica de um país e compreender seu comportamento pode ajudar na definição de políticas que favoreçam a retomada do crescimento econômico nacional.<br>
#
# > Who? <br>
# >> Os dados foram disponibilizados pelo Ministério da Indústria, Comércio Exterior e Serviços do Brasil. <br>
#
# > What? <br>
# >> O objetivo dessa análise é tão somente conhecer como foi a repercussão imediata da pandemia nas importações realizadas pelo Brasil e projetar o comportamento esperado para o ano de 2021. <br>
#
# > Where? <br>
# >> A análise envolverá os países, os valores de importação e as mercadorias comercializadas. <br>
#
# > When? <br>
# >> Por se tratar do impacto imediato, analisaremos o período de janeiro/2019 a junho/2021.<br>
#
#
# <br><br> Para isso, primeiramente, serão recuperados dados de importação de mercadorias referentes aos períodos em questão.
# <br><br> Por fim, far-se-á a comparação entre os valores mês a mês para verificar como se deu o impacto da pandemia.
#
#
# ### 2. A coleta de dados <br>
# Os datasets usados neste trabalho foram coletados conforme abaixo, em Julho/2021.
# > https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2019_V2.csv - contém os dados de importação referentes ao ano de 2019, mês a mês.<br>
# > https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2020_V2.csv - contém os dados de importação referentes ao ano de 2020, mês a mês.<br>
# > https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2021_V2.csv - contém os dados de importação referentes ao ano de 2021, até o mês de junho.<br>
# > https://balanca.economia.gov.br/balanca/bd/tabelas/NCM.csv - tabela auxiliar de códigos NCM <br>
# > https://balanca.economia.gov.br/balanca/bd/tabelas/PAIS.csv - tabela auxiliar de países <br>
# > https://balanca.economia.gov.br/balanca/bd/tabelas/UF.csv - tabela auxiliara ds de Unidades da Federação <br>
#
# <br> Os dados foram obtidos das Estatísticas de Comércio Exterior em Dados Abertos, cujas bases podem ser encontradas em __http://comexstat.mdic.gov.br/pt/home__, do Portal Comex Stat.
#
# <br> As tabelas abaixo definem os campos dos datasets de trabalho:
#
# <table width=100% align=left>
#   <caption>Tabela de dados estatísticos anos 2019, 2020 e até jan-jun/2021 </caption>
#   <tr>
#     <th>Nome do campo</th>
#     <th>Descrição</th>
#     <th>Tipo</th>
#   </tr>
#   <tr>
#     <td>CO_ANO</td>
#     <td>Ano da importação</td>
#     <td>Inteiro</td>
#     <td>  </td>
#   </tr>
#   <tr>
#     <td>CO_MES</td>
#     <td>Mês da importação</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_NCM</td>
#     <td>Código NCM do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_UNID</td>
#     <td>Código da unidade estatística</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PAIS</td>
#     <td>Código de país de origem do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>SG_UF_NCM</td>
#     <td>código da UF de destino do produto</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>CO_VIA</td>
#     <td>código da via de transporte</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_URF</td>
#     <td align=left>código da Unidade da Receirta Federal de desembarque</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>QT_ESTAT</td>
#     <td>quantidade estatística do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>KG_LIQUIDO</td>
#     <td>quilograma líquido do produto</td>
#     <td>Float</td>
#   </tr>
#   <tr>
#     <td>VL_FOB</td>
#     <td>valor FOB,em dólar</td>
#     <td>Float</td>
#   </tr>
#   <tr>
#     <td>VL_FRETE</td>
#     <td>valor frete,em dólar</td>
#     <td>Float</td>
#   </tr>
#   <tr>
#     <td>VL_SEGURO</td>
#     <td>valor do seguro,em dólar</td>
#     <td>Float</td>
#   </tr>
# </table>
#
# <table  width=100% align=left>
#   <caption>Tabela de países</caption> <br>
#   <tr>
#     <th>Nome do campo</th>
#     <th>Descrição</th>
#     <th>Tipo</th>
#   </tr>
#   <tr>
#     <td>CO_PAIS</td>
#     <td>Código do país de origem</td>
#     <td>inteiro</td>
#     <td>  </td>
#   </tr>
#   <tr>
#     <td>CO_PAIS_ISON3</td>
#     <td>Código do país de origem</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PAIS_ISOA3</td>
#     <td>Código do país de origem</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_PAIS</td>
#     <td>Nome do país em português</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_PAIS_ING</td>
#     <td>Nome do país em inglês</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_PAIS_ESP</td>
#     <td>Nome do país em espanhol</td>
#     <td>String</td>
#   </tr>
# </table>
#
# <table  width=100% align=left>
#   <caption>Tabela de Unidades da Federação</caption>
#   <tr>
#     <th>Nome do campo</th>
#     <th>Descrição</th>
#     <th>Tipo</th>
#   </tr>
#   <tr>
#     <td>CO_UF</td>
#     <td>Código da Unidade da Federação</td>
#     <td>Inteiro</td>
#     <td>  </td>
#   </tr>
#   <tr>
#     <td>SG_UF</td>
#     <td>Sigla da Unidade da Federação</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_UF</td>
#     <td>Nome da Unidade da Federação</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_REGIAO</td>
#     <td>Região a que pertence a Unidade da Federação</td>
#     <td>String</td>
#   </tr>
# </table>
#
# <table width=100% align=left>
#   <caption>Tabela de NCM </caption>
#   <tr>
#     <th>Nome do campo</th>
#     <th>Descrição</th>
#     <th>Tipo</th>
#   </tr>
#   <tr>
#     <td>CO_NCM</td>
#     <td>Código NCM da mercadoria</td>
#     <td>Inteiro</td>
#     <td>  </td>
#   </tr>
#   <tr>
#     <td>CO_UNID</td>
#     <td>Código da Unidade de Medida Estatística</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_SH6</td>
#     <td>Código SH da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PPE</td>
#     <td>Código PPE da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PPI</td>
#     <td>Código PPI da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_FAT_AGREG</td>
#     <td>Código de fator agregado da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_CUCI_ITEM</td>
#     <td>Código CUCI do item</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_CGCE_N3</td>
#     <td>Código CGCE</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_SIIT </td>
#     <td>Código SIIT do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_ISIC_CLASSE </td>
#     <td>Código ISIC da classse do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_EXP_SUBSET </td>
#     <td>Código EXP do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>NO_NCM_POR </td>
#     <td>Descrição da NCM em português</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_NCM_ESP </td>
#     <td>Descrição da NCM em espanhol</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_NCM_ING </td>
#     <td>Descrição da NCM em inglês</td>
#     <td>String</td>
#   </tr>
# </table>
#
# <br><br>
#
# <br><br><br>

# %%
#Células de imports
import pandas as pd
import csv
import ssl #para desabilitar a verificação de segurança SSL. 
#import os
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

import time
# Definindo parâmetros de apresentação
# Casas decimais 
pd.set_option("display.precision", 0)
# define apresentação de floats sem notação científica
pd.set_option('float_format',lambda x: "%.f" % x)

# %%
#************************CÉLULA DE COLETA DE DADOS *****************************

#Função para aquisição dos datasets
def get_datasets(urls_Datasets):
    
    #Desabilita verificação SSL
    ssl._create_default_https_context = ssl._create_unverified_context

    for url, destino in urls_Datasets.items(): 
        
        if not Path.exists(Path(destino)):
            try:
                df_temp = pd.read_csv(url, sep=';', encoding = 'cp1250')
                df_temp.to_csv(destino, sep=';',encoding = 'cp1250', index=False)
            except IOError:
                print("Um problema ocorreu processando %s ", destino)
                raise
#Fim da função

#Dicionário contendo as urls a serem acessadas e os arquivos de destino dos dados coletados
urls_Datasets = {
                 'https://balanca.economia.gov.br/balanca/bd/tabelas/PAIS.csv': 'Datasets/pais.csv',
                 'https://balanca.economia.gov.br/balanca/bd/tabelas/UF.csv'  : 'Datasets/uf.csv',
                 'https://balanca.economia.gov.br/balanca/bd/tabelas/NCM.csv' : 'Datasets/ncm.csv',
                 'https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2019_V2.csv':'Datasets/importacoes2019.csv',
                 'https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2020_V2.csv':'Datasets/importacoes2020.csv',
                 'https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2021_V2.csv':'Datasets/importacoes2021.csv'

                }

get_datasets(urls_Datasets)

# %% [markdown]
# ### 3.processamento e o tratamento dos dados <br>
# Analisando a estrutura dos datasets obtidos, observa-se que quase todos têm colunas que podem ser excluídas, com excessão da tabela de Unidades da Federação, sem que haja prejuízo à análise proposta. <br>
# Referidas colunas remetem a códigos não utilizados na análise e a descrições em idiomas diferentes do português.
# Os dados mantidos são importantes para:
# > estabelecer relacionamentos entre os datasets <br>
# > categorizar dados analisados
#
# A seguir, mostraremos as alterações realizadas:
#
# #### Tabela de países <br>
# Serão mantidas apenas as colunas CO_PAIS e NO_PAIS e excluídas as seguintes: <br>
#
# <table width=50% align=center>
#     <caption> Colunas a serem excluídos da tabela de países </caption>
#     <tr>
#        <th>Nome do campo</th>
#        <th>Tipo</th>
#     </tr>
#     <tr>
#         <td> CO_PAIS_ISON3 </td>
#         <td> inteiro       </td>
#     </tr>
#     <tr>
#         <td> CO_PAIS_ISOA3 </td>
#         <td> string        </td>
#     </tr>
#     <tr>
#         <td> NO_PAIS_ING   </td>
#         <td> string        </td>
#     </tr>
#     <tr>
#         <td> NO_PAIS_ESP   </td>
#         <td> string        </td>
#     </tr>
# </table>
# <br>
#
# Abaixo o código usado para a operação de exclusão de colunas:
# ![image.png](attachment:image.png)
#
# <br>E a seguir a nova configuração da tabela de países:
# ![image-2.png](attachment:image-2.png)
#
#
# #### Tabela de NCMs<br>
# Serão mantidas apenas as colunas CO_NCM e NO_NCM_POR.<br>
# A estrutura do dataset é a que se segue:
# ![image-22.png](attachment:image-22.png)
#
# <br> Como são muitas as colunas a serem excluídas, utilizaremos outra estratégia de deleção, conforme no trecho de código abaixo:
# ![image-5.png](attachment:image-5.png)
#
# <br>E a seguir a nova configuração da tabela de NCMs
# ![image-4.png](attachment:image-4.png)
#
# #### Datasets de importações de 2019 a 2021<br>
# Esses datasets têm uma quantidade grande de registros e estrutura idêntica.
# Assim, primeiro concatenaremos todos num só dataframe, a seguir eliminaremos as colunas CO_VIA, CO_UNID e CO_URF e deletaremos registros que não interessam para nosso trabalho, o que permitirá uma redução na poluição do dataset e  no uso de memória de máquina.
# <br>Aqui, trecho de código usado para obter a informação sobre o tamanho dos datasets de importações e que revela a estrutura idêntica entre eles, e o resultado mostrado na figura seguinte:
#
# ![image-17.png](attachment:image-17.png)
#
# ![image-19.png](attachment:image-19.png)
#
# 1. A concatenação dos datasets
# > Como já informado, os datasets de importações têm estruturas idênticas.
# Pela necessidade de se fazer uma série de operações neles, concatenaremos os dados para fazer as análises.
# ![image-18.png](attachment:image-18.png)
#
# 2. A eliminação de colunas que não serão utilizadas para a análise proposta
# > A seguir serão excluídas as colunas CO_UNID, CO_URF, CO_VIA, VL_FRETE e VL_SEGURO, uma vez que não serem objetos de análise neste trabalho.
#
# ![image-23.png](attachment:image-23.png)
#
# 3. Observa-se, ainda, na figura acima valores convertidos para float.
#
# #### Excluindo valores nulos nos datasets de importação
# Na nossa análise, eliminaremos os registros/linhas com VL_FOB e QT_ESTAT quando forem iguais a ZERO.
# <br>
#
# <br> Decidi apagar os registros com valores zerados desses campos pelos motivos seguintes:<br>
# - 1. Grande quantidade de registros do datasets.
# - 2. A utilização da média traria inconsistências para as análises, uma vez que esses registros podem referir-se a mercadorias de natureza totalmente diferentes e de preços igualmente díspares, podendo inclusive criar outliers.
# <br>
#
# <br> A figura abaixo, demonstra a existência desses valores zerados no dataset "IMPORTAÇÕES 2020".<br>
# ![image-15.png](attachment:image-15.png)
#
#
# O trecho de código a seguir exemplifica a execução dessa tarefa.
# ![image-16.png](attachment:image-16.png)
#
# #### Criando uma coluna com valores unitários das mercadorias em cada operação.
# Para fins de comparação entre os perídos, criaremos no dataset de importações uma coluna que registrará o valor unitário da mercadoria importada.
# Para isso, como pode ser visto na figura abaixo, somaremos os campos VL_FOB, VL_FRETE e VL_SEGURO e dividiremos pelo campo QT_ESTAT, que representa a quantidade importada.
#
# ![image-21.png](attachment:image-21.png)
#
# #### A detecção e o tratamento de outliers
#
# Para verificar a existência ou não de outliers no dataset, utilizaremos a análise de gráficos boxplot.
# O trecho de código abaixo indica essa tarefa.
#
# ![image-24.png](attachment:image-24.png)
#
# Como a quantidade de registros passa da casa de milhões, decidimos por agregar os valores de importação por mês e an, desenhando o gráfico com base na soma e na média aritmética dos períodos.
# Como se vê abaixo, não foram detectados outliers na distribuição.
# ![image-25.png](attachment:image-25.png)
#
# O scatter plot para a mesma distribuição também não indica a existência de valores outliers, como se pode ver na próxima figura.
#
# ![image-26.png](attachment:image-26.png)
#
#
# ### Análise e Exploração dos Dados
#
# Utilizaremos alguns parâmetros para embasar nossa análise.
# Os principais valores envolvidos são os valores das operações de importação, a quantidade e o peso das mercadorias dentro do período analisado.
#
# olha dfadsfsda __Bold por favor__ <br>
# _Italico Olha isso_ <br>
# $ a + bX$ <br>
# __________ dfjlkaj dlkjf lkajkdj
# > item
# >>item2
# >>>item3
# - item 1
# - item 2
# 1. item 1
# 2. item 2 <br>
# <font color=blue>"font color=blue"</font><br>
# paragrafog <br> outro paragrafo<br>
# #isto é comentário

# %%
#***********************Verificar a presença dos datasets e estatísticas dos dados coletados************************

df_Pais = Path('Datasets/pais.csv')   
df_UF = Path('Datasets/uf.csv')   
df_NCM = Path('Datasets/ncm.csv')
df_imp2019 = Path('Datasets/importacoes2019.csv')
df_imp2020 = Path('Datasets/importacoes2020.csv')
df_imp2021 = Path('Datasets/importacoes2021.csv')

lista_Tabelas = [df_Pais, df_UF, df_NCM, df_imp2019, df_imp2020, df_imp2021]

#verifica se todos os datasets estão presentes
for tabela in lista_Tabelas:
    if not Path.exists(tabela):
        print("Tabela ", tabela, "não encontrada. O script será interrompido.")
        exit(keep_kernel=True)

# %%
print("***********Informações sobre tabela de países \n")        

df_pais = pd.read_csv('Datasets/pais.csv', sep=';', encoding='cp1250')
#df_pais.rename(columns = {"CO_PAIS": "pais",
#                         "NO_PAIS": "nome_pais"}, inplace =True)

#df_pais[['CO_PAIS_ISON3','CO_PAIS_ISOA3', 'NO_PAIS_ING']].head(10) #Exibição de algumas colunas

#Deletando as colunas que não interessam para a análise
cols_to_drop = ['CO_PAIS_ISON3','CO_PAIS_ISOA3','NO_PAIS_ING','NO_PAIS_ESP']
df_pais.drop(cols_to_drop, axis=1, inplace=True)
#df_pais[df_pais.columns] = df_pais[df_pais.columns].astype('category')
#df_pais.set_index('pais',drop = False)
df_pais.head()
# Out:
# ***********Informações sobre tabela de países
#    CO_PAIS                 NO_PAIS
# 0        0            Năo Definido
# 1       13             Afeganistăo
# 2       15            Aland, Ilhas
# 3       17                 Albânia
# 4       20  Alboran-Perejil, Ilhas

# %%
print("\n***********Informações sobre tabela de NCMs \n")        
df_NCM = pd.read_csv('Datasets/ncm.csv', sep=';', encoding='cp1250').rename(columns={'CO_NCM':'ncm',
                                                                                    'NO_NCM_POR':'ncm_port'})
df_NCM.info()

#Deletando as colunas que não interessam para a análise
#Como são muitas colunas a deletar, usaremos o método de re-assignment para maior clareza
df_NCM = df_NCM[['ncm', 'ncm_port']]
df_NCM[df_NCM.columns] = df_NCM[df_NCM.columns].astype('category')

# %%
#***********Lendo as informações do dataset de importações dos anos 2019 a jun/2021***********

df_imp2019 = pd.read_csv('Datasets/importacoes2019.csv', sep=';', encoding='cp1250')

df_imp2020 = pd.read_csv('Datasets/importacoes2020.csv', sep=';', encoding='cp1250')

df_imp2021 = pd.read_csv('Datasets/importacoes2021.csv', sep=';', encoding='cp1250')
df_imp2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986532 entries, 0 to 986531
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   CO_ANO      986532 non-null  int64
#  1   CO_MES      986532 non-null  int64
#  2   CO_NCM      986532 non-null  int64
#  3   CO_UNID     986532 non-null  int64
#  4   CO_PAIS     986532 non-null  int64
#  5   SG_UF_NCM   986532 non-null  object
#  6   CO_VIA      986532 non-null  int64
#  7   CO_URF      986532 non-null  int64
#  8   QT_ESTAT    986532 non-null  int64
#  9   KG_LIQUIDO  986532 non-null  int64
#  10  VL_FOB      986532 non-null  int64
#  11  VL_FRETE    986532 non-null  int64
#  12  VL_SEGURO   986532 non-null  int64
# dtypes: int64(12), object(1)
# memory usage: 97.8+ MB

# %%
#Concatenando os datasets
df_importacoes = pd.concat([df_imp2019, df_imp2020,df_imp2021])
#Atribuindo tipo 'category' a algumas colunas
for col in ['CO_ANO', 'CO_MES', 'CO_NCM', 'CO_PAIS','SG_UF_NCM']: 
    df_importacoes[col] = df_importacoes[col].astype('category')
    
df_importacoes.dropna(inplace=True) # apagando registros nulos    
df_importacoes.reset_index(drop=True, inplace=True) #Para reorganização dos índices
print(df_importacoes.shape)
df_importacoes.info()

# %%
#Excluindo colunas de dataframe de importações
if set(['CO_UNID', 'CO_URF','CO_VIA', 'VL_FRETE', 'VL_SEGURO']).issubset(df_importacoes.columns):
    df_importacoes.drop(['CO_UNID', 'CO_URF','CO_VIA', 'VL_FRETE', 'VL_SEGURO'], axis=1, inplace=True)

#Convertando valores KG_LIQUIDO, VL_FOB, VL_FRETE e VL_SEGURO para float
df_importacoes['VL_FOB'] = df_importacoes['VL_FOB'].astype(float)
df_importacoes['KG_LIQUIDO'] = df_importacoes['KG_LIQUIDO'].astype(float)
df_importacoes.dtypes  #verificando se os tipos foram alterados
df_importacoes.info()

# %%
#Deletando valores zerados para QT_ESTAT e VL_FOB 
#Verificando quantidade de valores zerados 
num_zeros = df_importacoes[(df_importacoes['QT_ESTAT'] == 0) &
              (df_importacoes['VL_FOB'] == 0)].count()

#Deletando se houver zero nos campos
if num_zeros.sum() > 0:
    df_importacoes.drop(df_importacoes.index[df_importacoes['QT_ESTAT'] == 0], inplace=True)
    df_importacoes.drop(df_importacoes.index[df_importacoes['VL_FOB'] == 0], inplace=True)

# %%
#Células de imports
import pandas as pd
import csv
import ssl #para desabilitar a verificação de segurança SSL. 
#import os
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

import time

# Use 2 decimal places in output display
pd.set_option("display.precision", 2)
# Don't wrap repr(DataFrame) across additional lines
pd.set_option("display.expand_frame_repr", False)
# Set max rows displayed in output to 20
pd.set_option("display.max_rows", 20)
# define apresentação de floats sem notação científica
pd.set_option('float_format',lambda x: "%.f" % x)

dtypes = {
    "CO_ANO": "object",
    "CO_MES": "int64",
    "CO_NCM": "object",
#    "CO_PAIS": "category",
}

df = pd.read_csv('Datasets/Imp_Consolidada',sep=',',
        #         parse_dates=[["CO_ANO", "CO_MES"]],
                 usecols=["CO_ANO", "CO_MES","CO_NCM", "CO_PAIS", "QT_ESTAT", "VL_FOB"],
                 dtype=dtypes
                ).rename(columns=
                        {"CO_ANO": "ano",
                         "CO_MES": "mes",
                         "CO_NCM": "ncm",
#                         "CO_PAIS": "pais",
                         "QT_ESTAT": "quantidade",
                         "VL_FOB": "valor"
                        })#.set_index("periodo")

# %%
#Verificando a existência de outliers com boxplots
plt.clf()
ano = df.ano #periodo.str.slice(0,4)#index.year
mes = df.mes #periodo.str.slice(4,2)#index.month #_name()
mes_ano = df.groupby([ano,mes])[['valor','quantidade']].agg(['sum'])
mes_ano.plot.box(subplots=False, figsize=(10,4), logy=True)
# Out:
# <AxesSubplot:>

# %%
plt.clf()
#Verificando a existência de outliers com gráfico scatter
ncm = df.groupby([ano,mes])[['valor','quantidade']].agg(['sum'])
ncm.plot(x='valor', y='quantidade', subplots=True, kind='scatter', loglog=True)

# %%
#Evolução mensal das operações
evolucao = df.groupby([ano,mes])[['valor', 'quantidade']]
evolucao.agg(['sum']).plot(subplots=True,kind='bar',figsize=(15,5), sharex = True, sharey = True)

# %%
evolucao = df.groupby([ano,mes])[['valor', 'quantidade']]
evolucao.agg(['sum']).plot(subplots=True,kind='line',figsize=(15,6), logy = True, sharex = True, sharey = True)
#df[df.ncm==1012100].pais.value_counts(normalize = False)
#df['ncm1012'] = df.ncm.str.slice(0,4)
#df.ncm1012.value_counts()
#df_importacoes.CO_NCM.value_counts()
#df_importacoes.CO_MES.value_counts()

# %%
#10 categorias de produtos mais vendidos
# %timeit
def agg_ano(df):
    res = df.query('ano == 2019')
    print(res)
    return res

df.groupby(['ano','ncm'])['quantidade'].apply(agg_ano)

#    .agg(['sum']).nlargest(20,['sum']) \
#    .sort_values(['ano','sum'])\
#    .plot(kind='barh', logx=True,figsize=(10,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a6cbfbf2c4a> in <module>
#       6     return res
#       7
# ----> 8 df.groupby(['ano','ncm'])['quantidade'].apply(agg_ano)
#       9
#      10 #    .agg(['sum']).nlargest(20,['sum']) \
#
# NameError: name 'df' is not defined

# %%
df20 = df[df['ano'] == '2020'].nlargest(5,'valor')
df20.groupby('CO_PAIS').valor.agg(['sum']).plot()#.pie(title = 'Maiores exportadores - em milhões US$', 
              #figsize = (7,7),fontsize = 10, subplots = True, autopct='%1.1f%%', legend = True)
# Out:
# <AxesSubplot:xlabel='CO_PAIS'>

# %%
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100)
            for l, s in zip(labels, df19.valor)],
    prop={'size': 11},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig1.transFigure,
)
df19 = df[df['ano'] == '2019'].nlargest(5,'valor')

df19.groupby('pais').valor.agg('sum').plot.pie(ylabel="",title = 'Maiores exportadores',
              figsize = (7,7),fontsize = 10, subplots = True, legend= True, labels=labels,
              autopct='%1.1f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1876bea1e90f> in <module>
#       3     labels=['%s, %1.1f%%' % (
#       4         l, (float(s) / total) * 100)
# ----> 5             for l, s in zip(labels, df19.valor)],
#       6     prop={'size': 11},
#       7     bbox_to_anchor=(0.0, 1),
#
# NameError: name 'df19' is not defined

# %%
lb21 = ["%.0f" % i for i in df21.valor]
df21 = df[df['ano'] == '2021'].nlargest(5,'valor')

df21.groupby('pais').valor.agg('sum').plot.pie(title = 'Maiores exportadores',
              figsize = (5,5),fontsize = 10, subplots = True, legend = False, labels=labels,
                                              autopct='%1.1f%%', ylabel = '')
# Out:
# array([<AxesSubplot:>], dtype=object)

# %%
dfjunt = df20.merge(df_pais, on='CO_PAIS', how='left')
dfjunt
labels = ["%s" % i for i in dfjunt.NO_PAIS]
labels
# Out:
# ['Japăo', 'Arábia Saudita', 'Noruega', 'Japăo', 'Estados Unidos']

# %%
#df_pais.set_index('pais',drop=False)#, inplace=True)

#paises=[]

#for pais in df19.pais.values:
#    paises.append(df_pais.loc[df_pais['pais'] == pais])
    

labels = ["%s" % i for i in dfjunt.NO_PAIS]
 
fig1, ax1 = plt.subplots(figsize=(5, 5))
fig1.subplots_adjust(0.3, 0, 1, 1)
 
ax1.set_prop_cycle("color", [theme(1. * i / len(df20))
                             for i in range(len(df20))])
 
_, _ = ax1.pie(df19.pais, startangle=90, radius=1800)
 
ax1.axis('equal')
 
total = sum(df19.valor)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100)
            for l, s in zip(labels, df20.valor)],
    prop={'size': 11},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig1.transFigure,
)
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-7f4d8afd706e> in <module>
#      12 fig1.subplots_adjust(0.3, 0, 1, 1)
#      13
# ---> 14 ax1.set_prop_cycle("color", [theme(1. * i / len(df20))
#      15                              for i in range(len(df20))])
#      16
#
# <ipython-input-13-7f4d8afd706e> in <listcomp>(.0)
#      12 fig1.subplots_adjust(0.3, 0, 1, 1)
#      13
# ---> 14 ax1.set_prop_cycle("color", [theme(1. * i / len(df20))
#      15                              for i in range(len(df20))])
#      16
#
# NameError: name 'theme' is not defined

# %%
#Verifica arquivo de dados obtido using scrapping technics
tab_precos = Path('listaNova.csv')
if Path.exists(tab_precos):
    df_precos = pd.read_csv(tab_precos)
else:
    print("Arquivo %s não encontrado", tab_precos)

# %%
#Transformando preços em float
df_precos['preco_minimo'] = pd.to_numeric(df_precos.preco_minimo, errors = 'coerce')
df_precos['preco_maximo'] = pd.to_numeric(df_precos.preco_maximo, errors = 'coerce')
df_precos.info()

# %%
f = pd.melt(df_precos, value_vars=['preco_minimo','preco_maximo'])
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, height = 4)
g = g.map(sns.histplot, "value")

# %%
df_precos.plot.scatter(x='preco_minimo',y='preco_maximo', grid=True, c='red',figsize=[6,3], layout=[1,2])

# %%
#Preparando limpeza de linhas que não parecem ser de telas LCD
# 1. Selecionando só linhas que contém o termo LCD.
#df_precos['selecionada'] = df_precos.descricao.str.contains('lcd',case=False) #('[Cc]harge|[Aa]dhesive|[Tt]ool[s]|[Gg]lue|[Ss]ticker|[Cc]lip|[Mm]achine')
#df_precos.drop((df_precos[df_precos['selecionada']==False].index), inplace=True) # deleta o que não contém é LCD

#nao_lcds = '[Cc]harge|[Aa]dhesive|[Tt]ool[s]|[Gg]lue|[Ss]ticker|[Cc]lip|[Mm]achine'
#df_precos['selecionada'] = df_precos.descricao.str.contains(nao_lcds)
#df_precos.drop((df_precos[df_precos['selecionada']==True].index), inplace=True) # deleta o que não parece ser lcd
#df_precos.info()

# %%
#Converter preços mínimos menores que 1 em preço máximo
df_precos.loc[(df_precos['preco_minimo'] < 1 ) ,'preco_minimo'] = df_precos.preco_maximo
df_precos.head()

# %%
#df_precos.info()
df_precos.eval("preco_medio = (preco_minimo+preco_maximo)/2", target = df_precos, inplace = True)
df_precos.describe() # estatísticas do dataframe


df_precos = df_precos.sort_values(by='preco_medio').reset_index(drop=True)
p25 = df_precos["preco_medio"].quantile(0.25)
p75 = df_precos['preco_medio'].quantile(0.75)
iqr = p75 - p25
print("p25 = %s, p75 = %s, iqr = %s ", p25, p75, iqr)

# %%
f = pd.melt(df_precos, value_vars=['preco_minimo','preco_maximo', 'preco_medio'])
g = sns.FacetGrid(f, col="variable",  col_wrap=3, sharex=False, sharey=False, height = 5)
g = g.map(sns.histplot, "value")

# %%
#sns.boxplot(x='preco_medio',data=df_precos)
plt.figure(figsize=(12,4))
plt.hist(df_precos['preco_medio'])
plt.title("Total number of prices: %s" % len(df_precos.index))
plt.xlabel("Mean Annual Temperature (Degrees Celcius)")

# Vertical lines for each percentile of interest
plt.axvline(df_precos['preco_medio'].quantile(0.25), linestyle='--', color='red')
plt.axvline(df_precos['preco_medio'].quantile(0.50), linestyle='-',  color='red')
plt.axvline(df_precos['preco_medio'].quantile(0.75), linestyle='--', color='red')

plt.show()

# %%
df_precos.drop(df_precos.index[df_precos['preco_medio'] > 354], inplace=True)

sns.boxplot(x='preco_maximo',data=df_precos)
df_precos.info()
