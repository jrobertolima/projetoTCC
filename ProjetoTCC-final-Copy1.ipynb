# %% [markdown]
# ### 1. Definição do problema <br>
# #### 1.1 Contextualização <br>
# <p> O ano de 2020 marcou o início da pandemia de COVID-19, causada pelo coronavírus (SARS-CoV-2)
# <br><br> É patente que a pandemia produz repercussões de ordem biomédica e epidemiológica em escala global. No entanto, também há fortes repercussões e impactos nas áreas social, econômica, política, ambiental e outras, sem precedentes na história recente das epidemias.
# <br><br> Segundo a Organização para a Cooperação e Desenvolvimento Econômico (OCDE), em razão do surto de coronavírus, a economia global pode crescer na taxa mais baixa desde 2009.
# <br><br> Uma das áreas da economia que sofreu forte impacto é o comércio exterior, em função da redução da atividade econômica em escala global.
# <br><br> O Brasil, como todo país inserido numa economia globalizada, também foi atingido pelos efeitos da economia, principalmente por ter a China como principal parceiro econômico.
# </p>
#
# #### 1.2 O problema proposto <br>
#  O objetivo deste trabalho é apresentar uma análise sobre as importações nos anos de 2019 (antes da pandemia) e 2020 (durante a pandemia) e projetar o resultado dessa atividade para 2021. <br>
# > Why? <br>
# >>  Uma das áreas da economia que sofreu forte impacto da pandemia de COVID-19 foi o comércio exterior, em função da redução da atividade econômica em escala global. A importação de mercadorias é importante indicador do estado da atividade econômica de um país e compreender seu comportamento pode ajudar na definição de políticas que favoreçam a retomada do crescimento econômico nacional.<br>
#
# > Who? <br>
# >> Os dados foram disponibilizados pelo Ministério da Indústria, Comércio Exterior e Serviços do Brasil. <br>
#
# > What? <br>
# >> O objetivo dessa análise é tão somente conhecer como foi a repercussão imediata da pandemia nas importações realizadas pelo Brasil e projetar o comportamento esperado para o ano de 2021. <br>
#
# > Where? <br>
# >> A análise envolverá os países, os valores de importação e as mercadorias comercializadas. <br>
#
# > When? <br>
# >> Por se tratar do impacto imediato, analisaremos o período de janeiro/2019 a junho/2021.<br>
#
#
# <br><br> Para isso, primeiramente, serão recuperados dados de importação de mercadorias referentes aos períodos em questão.
# <br><br> Por fim, far-se-á a comparação entre os valores mês a mês para verificar como se deu o impacto da pandemia.
#
#
# ### 2. A coleta de dados <br>
# Os datasets usados neste trabalho foram coletados conforme abaixo, em Julho/2021.
# > https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2019_V2.csv - contém os dados de importação referentes ao ano de 2019, mês a mês.<br>
# > https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2020_V2.csv - contém os dados de importação referentes ao ano de 2020, mês a mês.<br>
# > https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2021_V2.csv - contém os dados de importação referentes ao ano de 2021, até o mês de junho.<br>
# > https://balanca.economia.gov.br/balanca/bd/tabelas/NCM.csv - tabela auxiliar de códigos NCM <br>
# > https://balanca.economia.gov.br/balanca/bd/tabelas/PAIS.csv - tabela auxiliar de países <br>
# > https://balanca.economia.gov.br/balanca/bd/tabelas/UF.csv - tabela auxiliara ds de Unidades da Federação <br>
#
# <br> Os dados foram obtidos das Estatísticas de Comércio Exterior em Dados Abertos, cujas bases podem ser encontradas em __http://comexstat.mdic.gov.br/pt/home__, do Portal Comex Stat.
#
# <br> As tabelas abaixo definem os campos dos datasets de trabalho:
#
# <table width=100% align=left>
#   <caption>Tabela de dados estatísticos anos 2019, 2020 e até jan-jun/2021 </caption>
#   <tr>
#     <th>Nome do campo</th>
#     <th>Descrição</th>
#     <th>Tipo</th>
#   </tr>
#   <tr>
#     <td>CO_ANO</td>
#     <td>Ano da importação</td>
#     <td>Inteiro</td>
#     <td>  </td>
#   </tr>
#   <tr>
#     <td>CO_MES</td>
#     <td>Mês da importação</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_NCM</td>
#     <td>Código NCM do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_UNID</td>
#     <td>Código da unidade estatística</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PAIS</td>
#     <td>Código de país de origem do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>SG_UF_NCM</td>
#     <td>código da UF de destino do produto</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>CO_VIA</td>
#     <td>código da via de transporte</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_URF</td>
#     <td align=left>código da Unidade da Receirta Federal de desembarque</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>QT_ESTAT</td>
#     <td>quantidade estatística do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>KG_LIQUIDO</td>
#     <td>quilograma líquido do produto</td>
#     <td>Float</td>
#   </tr>
#   <tr>
#     <td>VL_FOB</td>
#     <td>valor FOB,em dólar</td>
#     <td>Float</td>
#   </tr>
#   <tr>
#     <td>VL_FRETE</td>
#     <td>valor frete,em dólar</td>
#     <td>Float</td>
#   </tr>
#   <tr>
#     <td>VL_SEGURO</td>
#     <td>valor do seguro,em dólar</td>
#     <td>Float</td>
#   </tr>
# </table>
#
# <table  width=100% align=left>
#   <caption>Tabela de países</caption> <br>
#   <tr>
#     <th>Nome do campo</th>
#     <th>Descrição</th>
#     <th>Tipo</th>
#   </tr>
#   <tr>
#     <td>CO_PAIS</td>
#     <td>Código do país de origem</td>
#     <td>inteiro</td>
#     <td>  </td>
#   </tr>
#   <tr>
#     <td>CO_PAIS_ISON3</td>
#     <td>Código do país de origem</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PAIS_ISOA3</td>
#     <td>Código do país de origem</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_PAIS</td>
#     <td>Nome do país em português</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_PAIS_ING</td>
#     <td>Nome do país em inglês</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_PAIS_ESP</td>
#     <td>Nome do país em espanhol</td>
#     <td>String</td>
#   </tr>
# </table>
#
# <table width=100% align=left>
#   <caption>Tabela de NCM </caption>
#   <tr>
#     <th>Nome do campo</th>
#     <th>Descrição</th>
#     <th>Tipo</th>
#   </tr>
#   <tr>
#     <td>CO_NCM</td>
#     <td>Código NCM da mercadoria</td>
#     <td>Inteiro</td>
#     <td>  </td>
#   </tr>
#   <tr>
#     <td>CO_UNID</td>
#     <td>Código da Unidade de Medida Estatística</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_SH6</td>
#     <td>Código SH da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PPE</td>
#     <td>Código PPE da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_PPI</td>
#     <td>Código PPI da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_FAT_AGREG</td>
#     <td>Código de fator agregado da mercadoria</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_CUCI_ITEM</td>
#     <td>Código CUCI do item</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_CGCE_N3</td>
#     <td>Código CGCE</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_SIIT </td>
#     <td>Código SIIT do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_ISIC_CLASSE </td>
#     <td>Código ISIC da classse do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>CO_EXP_SUBSET </td>
#     <td>Código EXP do produto</td>
#     <td>Inteiro</td>
#   </tr>
#   <tr>
#     <td>NO_NCM_POR </td>
#     <td>Descrição da NCM em português</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_NCM_ESP </td>
#     <td>Descrição da NCM em espanhol</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>NO_NCM_ING </td>
#     <td>Descrição da NCM em inglês</td>
#     <td>String</td>
#   </tr>
# </table>
#
# <br><br>
#
# <br><br><br>

# %%
#*************************CÉLULAS DE IMPORTAÇÃO DE BIBLIOTECAS********************
import pandas as pd
import numpy as np
import csv
import ssl #para desabilitar a verificação de segurança SSL. 

import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

from statsmodels.stats.diagnostic import normal_ad, het_breuschpagan

from wordcloud import WordCloud 

import time
from pathlib import Path
import warnings

# Definindo parâmetros de apresentação

# %matplotlib inline

warnings.filterwarnings('ignore')
pd.set_option("display.precision", 0)
pd.set_option('float_format',lambda x: "%.2f" % x)

# %%
#************************CÉLULA DE COLETA DE DADOS *****************************

#Função para aquisição dos datasets
def get_datasets(urls_Datasets):
    
    #Desabilita verificação SSL
    ssl._create_default_https_context = ssl._create_unverified_context

    for url, destino in urls_Datasets.items(): 
        
        if not Path.exists(Path(destino)):
            try:
                df_temp = pd.read_csv(url, sep=';', encoding = 'cp1250')
                df_temp.to_csv(destino, sep=';',encoding = 'cp1250', index=False)
            except IOError:
                print("Um problema ocorreu processando %s ", destino)
                raise
#Fim da função

#Dicionário contendo as urls a serem acessadas e os arquivos de destino dos dados coletados
urls_Datasets = {
                 'https://balanca.economia.gov.br/balanca/bd/tabelas/PAIS.csv': 'Datasets/pais.csv',
                 'https://balanca.economia.gov.br/balanca/bd/tabelas/UF.csv'  : 'Datasets/uf.csv',
                 'https://balanca.economia.gov.br/balanca/bd/tabelas/NCM.csv' : 'Datasets/ncm.csv',
                 'https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2019_V2.csv':'Datasets/importacoes2019.csv',
                 'https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2020_V2.csv':'Datasets/importacoes2020.csv',
                 'https://balanca.economia.gov.br/balanca/bd/comexstat-bd/ncmv2/IMP_2021_V2.csv':'Datasets/importacoes2021.csv'

                }

get_datasets(urls_Datasets)

# %% [markdown]
# ### 3.processamento e o tratamento dos dados <br>
# Analisando a estrutura dos datasets obtidos, observa-se que quase todos têm colunas que podem ser excluídas, com excessão da tabela de Unidades da Federação, sem que haja prejuízo à análise proposta. <br>
# Referidas colunas remetem a códigos não utilizados na análise e a descrições em idiomas diferentes do português.
# Os dados mantidos são importantes para:
# > estabelecer relacionamentos entre os datasets <br>
# > categorizar dados analisados
#
# A seguir, mostraremos as alterações realizadas:

# %%
#***********************Verifica a presença dos datasets e estatísticas dos dados coletados************************

lista_tabelas = [
              'pais.csv',
              'uf.csv', 
              'ncm.csv',
              'importacoes2019.csv',
              'importacoes2020.csv',
              'importacoes2021.csv'
             ]

#verifica se todos os datasets estão presentes
for tabela in lista_tabelas:
    if not Path.exists(Path('Datasets/'+tabela)):
        print("Tabela ", tabela, "não encontrada. O script será interrompido.")
        exit(keep_kernel=True)

# %% [markdown]
# #### Tabela de países <br>
# Serão mantidas apenas as colunas CO_PAIS e NO_PAIS e excluídas as seguintes: <br>
#
# <table width=50% align=center>
#     <caption> Colunas a serem excluídos da tabela de países </caption>
#     <tr>
#        <th>Nome do campo</th>
#        <th>Tipo</th>
#     </tr>
#     <tr>
#         <td> CO_PAIS_ISON3 </td>
#         <td> inteiro       </td>
#     </tr>
#     <tr>
#         <td> CO_PAIS_ISOA3 </td>
#         <td> string        </td>
#     </tr>
#     <tr>
#         <td> NO_PAIS_ING   </td>
#         <td> string        </td>
#     </tr>
#     <tr>
#         <td> NO_PAIS_ESP   </td>
#         <td> string        </td>
#     </tr>
# </table>
# <br>
#
# Abaixo o código usado para a operação de exclusão de colunas. O artifício usado foi de selecionar as colunas de interesse para o dataset no momento da leitura do arquivo:
#
# <br>E a seguir a nova configuração da tabela de países e uma amostra da tabela:

# %%
#*************** Prepara informações sobre tabela de países*********************        
df_pais = pd.read_csv('Datasets/pais.csv', sep=';', encoding='cp1250',
                     usecols = ['CO_PAIS', 'NO_PAIS']
                     )
#Renomeia os nomes de colunas para maior clareza
df_pais.rename(columns = {"CO_PAIS": "pais", 
                          "NO_PAIS": "nome_pais"
                         }, inplace =True)
df_pais['pais'] = df_pais['pais'].astype('object')
df_pais.info()
df_pais.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pais       281 non-null    object
#  1   nome_pais  281 non-null    object
# dtypes: object(2)
# memory usage: 4.5+ KB
#   pais               nome_pais
# 0    0            Năo Definido
# 1   13             Afeganistăo
# 2   15            Aland, Ilhas
# 3   17                 Albânia
# 4   20  Alboran-Perejil, Ilhas

# %% [markdown]
# #### Tabela de NCMs
# Serão mantidas apenas as colunas CO_NCM e NO_NCM_POR.<br>
#
# Como são muitas as colunas a serem excluídas, utilizaremos a mesma estratégia de deleção, conforme no trecho de código abaixo:
# <br>Segue-se a nova configuração da tabela de NCMs e uma amostra da mesma.

# %%
#*************** Prepara informações sobre tabela de NCM das mercadorias*********************        
df_ncm = pd.read_csv('Datasets/ncm.csv', sep=';', encoding='cp1250',
                     usecols = ['CO_NCM', 'NO_NCM_POR']
                     )
#Renomeia os nomes de colunas para maior clareza
df_ncm.rename(columns = {"CO_NCM": "ncm", 
                          "NO_NCM_POR": "descricao" 
                         }, inplace =True)
df_ncm['ncm'] = df_ncm['ncm'].astype('category')
df_ncm.info()
df_ncm.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13123 entries, 0 to 13122
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ncm        13123 non-null  category
#  1   descricao  13123 non-null  object
# dtypes: category(1), object(1)
# memory usage: 870.8+ KB
#         ncm                                          descricao
# 0  38085910  Outras mercadorias mencionadas na Nota de subp...
# 1  38085921  Mercadorias ŕ base de metamidofós (ISO) ou mon...
# 2  38085922  Mercadorias ŕ base de endossulfan (ISO), apres...
# 3  38085923  Mercadorias ŕ base de alaclor (ISO), apresenta...
# 4  38085929  Mercadorias ŕ base de outras substâncias, apre...

# %% [markdown]
# #### Datasets de importações de 2019 a 2021
# Esses datasets têm uma quantidade grande de registros e estrutura idêntica.<br>
# Assim, primeiro os recuperaremos separadamente, os concatenaremos todos num só dataframe, a seguir eliminaremos as colunas CO_VIA, CO_UNID e CO_URF e deletaremos registros que não interessam para nosso trabalho, o que permitirá uma redução na poluição do dataset e  no uso de memória de máquina. <br>
# <br>Desta vez, já definiremos os tipos dos campos no momento da recuperação dos arquivos e criação dos respectivos dataframes, usando o parâmetro _dtypes_, que descreve um tipo dicionário.
# <br>Mostraremos em seguida o trecho de código usado para obter a informação sobre o tamanho dos datasets de importações e que revela a estrutura idêntica entre eles, usando como exemplo o dataset referente às importações do ano de 2019:

# %%
#***********Lendo as informações do dataset de importações dos anos 2019 a jun/2021***********

#Por haver muitas colunas que não serão utilizadas, faremos a exclusão das desnecessárias posteriormente
dtypes = {
    "CO_ANO"    : "object",
    "CO_MES"    : "category",
    "CO_NCM"    : "int64",
    "CO_PAIS"   : "int64",
    "QT_ESTAT"  : "float",
    "VL_FOB"    : "float",
    "KG_LIQUIDO": "float",
}

df_imp2019 = pd.read_csv('Datasets/importacoes2019.csv', sep=';', encoding='cp1250',
                         dtype=dtypes,
                         usecols=list(dtypes)
                         )

df_imp2020 = pd.read_csv('Datasets/importacoes2020.csv', sep=';', encoding='cp1250',
                         dtype=dtypes,
                         usecols=list(dtypes)
                         )

df_imp2021 = pd.read_csv('Datasets/importacoes2021.csv', sep=';', encoding='cp1250',
                         dtype=dtypes,
                         usecols=["CO_ANO"] + list(dtypes)
                         )

df_imp2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1932755 entries, 0 to 1932754
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      object
#  1   CO_MES      category
#  2   CO_NCM      int64
#  3   CO_PAIS     int64
#  4   QT_ESTAT    float64
#  5   KG_LIQUIDO  float64
#  6   VL_FOB      float64
# dtypes: category(1), float64(3), int64(2), object(1)
# memory usage: 90.3+ MB

# %% [markdown]
# 1. A concatenação dos datasets
# > Como já informado, os datasets de importações têm estruturas idênticas.
# Pela necessidade de se fazer uma série de operações neles, concatenaremos os dados para fazer as análises.
# <br> Podemos observar que a estrutura se manteve.
# <br> Abaixo, a amostra dos últimos registros do dataset.

# %%
#**************Pelo fato de a estrutura das tabelas serem idênticas, concatenaremos os datasets
df_importacoes = pd.concat([df_imp2019, df_imp2020,df_imp2021])

#Limpando registros nulos, caso existam
df_importacoes.dropna(inplace=True)  

#Reorganização os índices
df_importacoes.reset_index(drop=True, inplace=True) 
df_importacoes.shape

df_importacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4703344 entries, 0 to 4703343
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      object
#  1   CO_MES      object
#  2   CO_NCM      int64
#  3   CO_PAIS     int64
#  4   QT_ESTAT    float64
#  5   KG_LIQUIDO  float64
#  6   VL_FOB      float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 251.2+ MB

# %%
df_importacoes.tail()
# Out:
#         CO_ANO CO_MES    CO_NCM  CO_PAIS  QT_ESTAT  KG_LIQUIDO  VL_FOB
# 4703339   2021      6  73269090      232      1.00        1.00 1161.00
# 4703340   2021      5  84842000       23      2.00        2.00 1826.00
# 4703341   2021      1  39269090      628     26.00       26.00 1724.00
# 4703342   2021      2  40093100      827     14.00       14.00  573.00
# 4703343   2021      5  85122021      249    133.00        5.00  580.00

# %% [markdown]
# 2. Faremos a renomeação das colunas para fins de melhor clareza e atendimento a um padrão de codificação.
# <br> O resultado é mostrado  abaixo.

# %%
#Renomeia os nomes de colunas para maior clareza
df_importacoes.rename(columns = {
    "CO_ANO"    : "ano",
    "CO_NCM"    : "ncm", 
    "CO_MES"    : "mes",
    "CO_PAIS"   : "pais",
    "QT_ESTAT"  : "quantidade",
    "KG_LIQUIDO": "peso",
    "VL_FOB"    : "valor"
     }, inplace =True)
df_importacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4703344 entries, 0 to 4703343
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ano         object
#  1   mes         object
#  2   ncm         int64
#  3   pais        int64
#  4   quantidade  float64
#  5   peso        float64
#  6   valor       float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 251.2+ MB

# %% [markdown]
# #### Excluindo valores nulos nos datasets de importação
# Na nossa análise, eliminaremos os registros/linhas com VL_FOB e QT_ESTAT quando forem iguais a ZERO.
# <br>
#
# <br> Decidi apagar os registros com valores zerados desses campos pelos motivos seguintes:<br>
# - 1. Grande quantidade de registros do datasets.
# - 2. A utilização da média traria inconsistências para as análises, uma vez que esses registros podem referir-se a mercadorias de natureza totalmente diferentes e de preços igualmente díspares, podendo inclusive criar outliers.
# <br>
#
# <br> Seguindo a codificação, demonstro a existência desses valores zerados no dataset.<br>
#
# <br> O trecho de código seguinte executa a deleção dos registros.

# %%
df_importacoes.query('quantidade == 0 | valor == 0')
# Out:
#           ano mes       ncm  pais  quantidade  peso   valor
# 58       2019   5  74152900   628        0.00  0.00    1.00
# 124      2019   7  29309079   399        0.00  0.00   31.00
# 127      2019  12  73181600   246        0.00  0.00    3.00
# 129      2019   3  29147919   249        0.00  0.00 2623.00
# 162      2019   1  39219090   275        0.00  0.00  566.00
# ...       ...  ..       ...   ...         ...   ...     ...
# 4703281  2021   6  96151900   386        0.00  0.00  531.00
# 4703289  2021   5  84679100    72        0.00  0.00   16.00
# 4703296  2021   4  40169300   149        0.00  0.00    8.00
# 4703303  2021   5  39269069    87        0.00  0.00   90.00
# 4703336  2021   5  33041000   399        0.00  0.00    2.00
#
# [328121 rows x 7 columns]

# %%
#******************************Deletando valores zerados para quantidade, peso e VL_FOB 
df_importacoes.drop(df_importacoes.index[df_importacoes['quantidade'] == 0], inplace=True)
df_importacoes.drop(df_importacoes.index[df_importacoes['valor'] == 0], inplace=True)
df_importacoes.drop(df_importacoes.index[df_importacoes['peso'] == 0], inplace=True)

# %% [markdown]
# #### A detecção e o tratamento de outliers
#
# Para verificar a existência ou não de outliers no dataset, utilizaremos a análise de gráficos boxplot.
#
# Como a quantidade de registros passa da casa de milhões, decidimos por agregar os valores de importação por ano e mês, desenhando o gráfico com base nessa soma.
# Como se vê abaixo, não foram detectados, por esse método, possíveis outliers na distribuição.
#
# O scatter plot para a mesma distribuição também não indica a existência de valores outliers, como se pode ver na próxima figura.<br>
# <br> No entanto, quando fazemos os boxplots para _quantidade, valor e peso_ separadamente, podemos notar a possível existênncia de _outliers_.

# %%
#***************************Verificando a possível existência de outliers de valor e quantidade com boxplots
plt.clf()
df_importacoes.groupby(['ano','mes'])[['valor','quantidade', 'peso']].agg(['sum']) \
                        .plot.box(subplots=False, figsize=(10,4), logy=True, sharex = False, sharey = False)
# Out:
# <AxesSubplot:>

# %%
plt.clf()
#Verificando a possível existência de outliers com gráfico scatter
ncm = df_importacoes.groupby(['ano','mes'])[['valor','quantidade']].agg(['sum'])
ncm.plot(x='valor', y='quantidade', subplots=True, kind='scatter', loglog=True, figsize = (10,4))
# Out:
# array([<AxesSubplot:xlabel='valor', ylabel='quantidade'>], dtype=object)

# %%
def plotBoxplot(data):
    fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(15,5))
    fig.tight_layout(pad=2.0)

    col = 0
    row = 0
    colors = ['#bad9e9', '#7ab6d6', '#3c8abd']

    for i, column in enumerate(data.columns):
        sns.boxplot(x=column, data=data, ax=axes[row][col], color=colors[col]) 

        if (i + 1) % 2 == 0:
            row += 1
            col = 0
        else:
            col += 1

# %%
#Detecting outliers :
plt.clf()
dfp = df_importacoes.drop(['ano', 'mes','ncm','pais'], axis=1)
plotBoxplot(dfp)

# %% [markdown]
# #### A detecção e o tratamento de outliers - parte 2
#
# Visando a excluir os possíveis _outliers_ do dataframe, utilizaremos o método da distância interquartílica, para definir os registros a serem apagados do dataset e observaremos o resultado.
# <br> Os boxplots com base no dataset sem os possíveis _"outliers"_ parecem revelar que aqueles registros não têm essa natureza, apesar de reduzir o dataset em mais de 50 MB. Assim, os manteremos nas nossas análises.

# %%
#Encontrando a distância interquartílica para quantidade peso e valor
Q1 = df_importacoes.quantile(0.25)
Q3 = df_importacoes.quantile(0.75)
IQR = Q3 - Q1

print(IQR)
# Out:
# ncm          43159900.00
# pais              239.00
# quantidade       1885.00
# peso             1147.00
# valor           22835.00
# dtype: float64

# %%
#*********************************Limpando de possíveis outliers******************************************
dfimp_out = df_importacoes[~((df_importacoes < (Q1 - 1.5 * IQR)) | (df_importacoes > (Q3 + 1.5 * IQR))).any(axis=1)]
dfimp_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3128735 entries, 0 to 4703343
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ano         object
#  1   mes         object
#  2   ncm         int64
#  3   pais        int64
#  4   quantidade  float64
#  5   peso        float64
#  6   valor       float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 191.0+ MB

# %%
dfp2 = dfimp_out.drop(['ano', 'mes','ncm','pais'], axis=1)
plotBoxplot(dfp2)

# %% [markdown]
# ### Análise e Exploração dos Dados
#
# Utilizaremos alguns parâmetros para embasar nossa análise.
# Os principais valores envolvidos são os valores das operações de importação, a quantidade e o peso das mercadorias dentro do período analisado.<br>
#
# Em primeiro lugar, temos a evolução dessas variáveis (peso, quantidade e valor) no período de 2019 até o primeiro semestre de 2021.
# <br> Fizemos também a mesma análise com base na média desses valores, na busca de confirmação de uma tendência.
# <br> Os códigos correspondentes e os gráficos vão a seguir.
#
# <br> Podemos observar uma queda importante nas variáveis no período que vai de abril/2020 a agosto/2020. Muito provavelmente, ela está vinculada à primeira onda da pandemia de COVID19.
# A retomada das atividades seguinte pode ter sido em função do fim da primeira onda.
# Os gráficos revelam, também, que o primeiro semestre de 2021 tem mostrado a retomada de atividades.
# As médias indicam a mesma situação.

# %%
df_importacoes.ano = df_importacoes.ano.astype('int64')
df_importacoes.mes = df_importacoes.mes.astype('int64')

# %%
#******************** Verificando a evolução mensal das operações ********
plt.clf()
evolucao = df_importacoes.groupby(['ano','mes'])[['valor', 'quantidade', 'peso']].agg(['sum'])
evolucao.plot(subplots=True,kind='bar',figsize=(12,8), sharex = True, sharey = False, logy = True, grid = True)
# Out:
# array([<AxesSubplot:title={'center':'(valor, sum)'}, xlabel='ano,mes'>,
#        <AxesSubplot:title={'center':'(quantidade, sum)'}, xlabel='ano,mes'>,
#        <AxesSubplot:title={'center':'(peso, sum)'}, xlabel='ano,mes'>],
#       dtype=object)

# %%
#******************** Verificando a evolução mensal das operações pela média ********
plt.clf()
evolucao = df_importacoes.groupby(['ano','mes'])[['valor', 'quantidade', 'peso']]
evolucao.agg(['mean']).plot(subplots=True,kind='line',figsize=(12,8), logy = True, sharex = True, sharey = True)
# Out:
# array([<AxesSubplot:xlabel='ano,mes'>, <AxesSubplot:xlabel='ano,mes'>,
#        <AxesSubplot:xlabel='ano,mes'>], dtype=object)

# %% [markdown]
# #### Análise e exploração dos dados - continuando
# > A partir daqui, vamos analisar se no período houve impacto quanto aos principais países exportadores e as principais mercadorias importadas.
# <br> Para isso, buscaremos os 6 maiores países exportadores e os 6 tipos de mercadorias mais negociadas. Faremos isso para cada ano separadamente: 2019, 2020 e 2021/1ºsemestre.

# %%
#Formata o label do gráfico
def lab(val,soma):
    absol = int(round(val/100.*soma)/1000000000)
    return "{:.1f}%\n(US${:d} Bi)".format(val, absol)
    
#Desenha o gráfico de pizza
def plota_pais(df):
    plt.clf()
    ano = df.iloc[1,0] # pega o ano referente ao dataset
    soma = df.valor.agg('sum') #Calcula o valor total importado no ano
    df = df.groupby('pais').valor.agg(['sum']).nlargest(6,'sum')

# 2. Nomes dos países maiores
    
    paises = df.merge(df_pais, on = 'pais', how = 'left')
    labels = ["%s" % i for i in paises.nome_pais]

# 3 Plota    
    df.plot.pie(title = 'Maiores exportadores - ' + str(ano),
              figsize = (5,5),fontsize = 10, subplots = True, legend = False, labels = labels,
                        ylabel = '', normalize = True,
                        autopct = lambda val: lab(val, soma)   )

# %%
#********************Verificando maiores exportadores em valor em 2019*********************
# 1. Definir maiores
df19 = df_importacoes[df_importacoes['ano'] == 2019]
plota_pais(df19)

# %%
#********************Verificando maiores exportadores em valor em 2020*********************
df20 = df_importacoes[df_importacoes['ano'] == 2020]
plota_pais(df20)

# %%
#********************Verificando maiores exportadores em valor em 2021*********************
df21 = df_importacoes[df_importacoes['ano'] == 2021]
plota_pais(df21)

# %% [markdown]
# ##### A análise dos maiores exportadores.
# > Os gráficos de pizza acima explicitam que houve pouca variação entre os parceiros do Brasil na exportação, permanecendo China, Estados Unidos, Alemanha e Argentina e variando México, Coreia do Sul, Japão e Índia.
# <br> Não obstante, confirmando a tendência de queda teve valores menores acumulados em 2019, bastante provavelmente em funçao da pandemia de COVID19.

# %%
def plota_ncm(df, color):
    ano = df.iloc[1,0] # pega o ano referente ao dataset

    # 2. Descrição das NCMs    
    df = df.groupby('ncm').peso.agg(['sum']).nlargest(6,'sum')

    ncms = df.merge(df_ncm, on = 'ncm', how = 'left')
    legend = ["%s" % i for i in ncms.descricao]
 
    ax = df.plot(title = 'Mercadorias mais negociadas - '+ str(ano),
                 kind='barh', figsize=(10, 4), 
                 color = color, zorder=2, width=0.70, legend = False
                 )

    # Despine
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

    # Switch off ticks
    ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
    
    # Draw vertical axis lines
    vals = ax.get_xticks()
    for tick in vals:
        ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Set x-axis label
    ax.set_xlabel("Quantidade por mil toneladas", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    ax.set_ylabel("NCMs", labelpad=20, weight='bold', size=12)

    # Format y-axis label
    ax.xaxis.set_major_formatter(lambda x, pos: str(x/1000000))

# %%
#********************Plota mercardorias mais negociadas 2019*********
plota_ncm(df19, 'y')

# %%
#********************8Plota mercardorias mais negociadas 2020*********
plota_ncm(df20, 'c')

# %%
#********************Plota mercardorias mais negociadas 2021*********
plota_ncm(df21, 'g')

# %% [markdown]
# ##### As mercadorias mais importadas
# > Os gráficos de barras demonstram não ter havido alterações nos tipos de mercadorias negociadas no período, deixando claro, porém, a redução nos respectivos volumes importados.
#
# ##### Nuvens de palavras
# > Para fins de verificação das tendências apontadas, em relação aos países exportadores e mercadorias mais negociadas, fizemos as nuvens de palavras referentes a essas variáveis nos anos de 2019 e 2020 e percebemos que houve mesmo pouca alteração desses valores.

# %%
#Países com quem mais se fez operações de importações. 
def impwc(df):
    wc = WordCloud(background_color="gray", max_words=100,
                   max_font_size=256,
                   random_state=42, width=1500, height=1500)
    wc.generate(' '.join(df))
    plt.imshow(wc)
    plt.axis('off')

# %%
#Wordcloud para países maiores
dfwc = df19.merge(df_pais, on = 'pais', how = 'left')
impwc(dfwc.nome_pais)

# %%
dfwc = df20.merge(df_pais, on = 'pais', how = 'left')
impwc(dfwc.nome_pais)

# %%
impwc(df19.merge(df_ncm, on = 'ncm', how = 'left').descricao)

# %%
impwc(df20.merge(df_ncm, on = 'ncm', how = 'left').descricao)

# %%
#df_importacoes[['pais','ncm','ano','mes']] = df_importacoes[['pais','ncm','ano','mes']].astype('int64')

# %% [markdown]
# ### 5. Machine learning
# Nosso objetivo é tentar construir um modelo de predição para a evolução do _valor das importações_ em função do _ano, mês_ e _país_.
# Para isso, vamos usar a Regressão Linear para tentar definir o modelo proposto.
# Verificaremos se a distribuição é normal.
# O código a seguir nos mostra o grau de assimetria de nossa distribuição.

# %%
#skewness and kurtosis
def skew(columns, df):
    dfs = df_importacoes[columns].agg(['skew', 'kurtosis']).transpose()
    for index, row in dfs.iterrows():
        if (abs(row['skew']) > 1):
            dfs.loc[index,'label'] = 'highly skewed'
        elif (0.5 < abs(row['skew']) < 1):
            dfs.loc[index,'label'] = 'moderately  skewed'
        else:
            dfs.loc[index,'label'] = 'approximately symmetric'
        
    return dfs

columns = ['valor','quantidade','peso','ncm']
#columns = ['quantidade','peso','ncm']
skew(columns, df_importacoes)
# Out:
#              skew  kurtosis               label
# valor      544.17 475547.50       highly skewed
# quantidade 112.78  17627.80       highly skewed
# peso        94.54  14286.54       highly skewed
# ncm         -0.91     -0.62  moderately  skewed

# %% [markdown]
# #### Machine learning - continuação
# > A tabela acima demonstra uma alta assimetria nas variáveis que utilizaremos no modelo.
# > Para corrigir tal característica, vamos transformar a distribuição de maneira a reduzir sua assimetria.

# %%
def transformDistribution(columns, method):
    fig, axes = plt.subplots(ncols=2, nrows=len(columns), figsize=(10, 8))
    fig.tight_layout(pad=4)
    
    for i, column in enumerate(columns):
        if method == 'sqrt':
            trans = np.sqrt(df_importacoes[column])
        elif method == 'log':
            trans = np.log10(df_importacoes[column]+1)
        else:
            trans, params = stats.boxcox(df[column]+1)
    
        sns.distplot(df_importacoes[column], ax=axes[i][0])
        sns.distplot(trans, ax=axes[i][1])

        axes[i][0].set_title('Distribution of {0}'.format(column))
        axes[i][1].set_title('Distribution of {0} (log)'.format(column))
        axes[i][1].set_xlabel('{0} (log)'.format(column))
        
    plt.show()
    
transformDistribution(['valor', 'quantidade', 'peso','ncm'], 'log')
#transformDistribution(['quantidade', 'peso','ncm'], 'log')

# %%
#df_importacoes['peso_log'] = np.log(df_importacoes['peso'])
#df_importacoes['valor_log'] = np.log(df_importacoes['valor'])
#df_importacoes['quantidade_log'] = np.log(df_importacoes['quantidade'])
#df_importacoes['ncm_log'] = np.log(df_importacoes['ncm'])
df21['peso_log'] = np.log(df21['peso'])
df21['valor_log'] = np.log(df21['valor'])
df21['quantidade_log'] = np.log(df21['quantidade'])
df21['ncm_log'] = np.log(df21['ncm'])

# %%
skew(['valor_log', 'quantidade_log','peso_log','ncm_log'], df21)
#skew(['quantidade_log','peso_log','ncm_log'], df_importacoes)
# Out:
#                 skew  kurtosis                    label
# valor_log       0.01     -0.25  approximately symmetric
# quantidade_log  0.43     -0.57  approximately symmetric
# peso_log        0.44     -0.47  approximately symmetric
# ncm_log        -2.13      6.86            highly skewed

# %%
dfScaled = minmax_scale(df21[['valor_log', 'quantidade_log','peso_log','ncm_log']])
#ncm_log não será reescalonado pois mudou de moderado para altamente assimétrico
#dfScaled = minmax_scale(df_importacoes[['valor_log','quantidade_log','peso_log','ncm_log']])

# %%
df21['valor_norm'] = dfScaled[:,0]
df21['quantidade_norm'] = dfScaled[:,1]
df21['peso_norm'] = dfScaled[:,1]
df21['ncm_norm'] = dfScaled[:,3]

df21.head()
# Out:
#           ano  mes       ncm  pais  quantidade    peso    valor  peso_log  \
# 3716812  2021    3  90319090    23       45.00   45.00 47011.00      3.81
# 3716813  2021    2  90322000   493       51.00    5.00   535.00      1.61
# 3716814  2021    4  29225011   361        1.00    1.00   124.00      0.00
# 3716815  2021    2  82100090   160     1096.00 1096.00  2306.00      7.00
# 3716816  2021    6  32099019   399      920.00  920.00 25699.00      6.82
#
#          valor_log  quantidade_log  ncm_log  valor_norm  quantidade_norm  \
# 3716812      10.76            3.81    18.32        0.55             0.18
# 3716813       6.28            3.93    18.32        0.32             0.19
# 3716814       4.82            0.00    17.19        0.24             0.00
# 3716815       7.74            7.00    18.22        0.39             0.33
# 3716816      10.15            6.82    17.28        0.52             0.32
#
#          peso_norm  ncm_norm
# 3716812       0.18      0.98
# ...

# %%
df21 = df21[['valor_norm', 'quantidade_norm','peso_norm','ano','pais','ncm','mes']]
df21.head()
# Out:
#          valor_norm  quantidade_norm  peso_norm   ano  pais       ncm  mes
# 3716812        0.55             0.18       0.18  2021    23  90319090    3
# 3716813        0.32             0.19       0.19  2021   493  90322000    2
# 3716814        0.24             0.00       0.00  2021   361  29225011    4
# 3716815        0.39             0.33       0.33  2021   160  82100090    2
# 3716816        0.52             0.32       0.32  2021   399  32099019    6

# %%
#Verificando se valor importado depende do mês, país e da ncm
#X = df_importacoes[['ano','mes','pais']]
X = df21[['ano','peso_norm']]
Y = df21['valor_norm']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
print('Linear Regression:')
print()
reg = LinearRegression()
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print('Accuracy:',reg.score(X_train, Y_train)*100)
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
sns.scatterplot(Y_pred, Y_test)
# Out:
# Linear Regression:
#
# Accuracy: 48.250979904856685
# Mean Absolute Error: 0.07032801503466289
# Mean Squared Error: 0.00856678551384795
# Root Mean Squared Error: 0.09255693120370809
# <AxesSubplot:ylabel='valor_norm'>

# %%
# Random Forest Regressor

print('Random Forest Regressor:')
print()
rfr = RandomForestRegressor()        
rfr.fit(X_train,Y_train)
Y_pred = rfr.predict(X_test)
print('Accuracy:',rfr.score(X_test, Y_test)*100)
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
sns.scatterplot(Y_pred, Y_test)
# Out:
# Random Forest Regressor:
#
# Accuracy: 47.886389047273845
# Mean Absolute Error: 0.07103020162807877
# Mean Squared Error: 0.008619785169948676
# Root Mean Squared Error: 0.0928427981587623
# <AxesSubplot:ylabel='valor_norm'>

# %%
df_importacoes.ano = df_importacoes.ano.astype('int64')
df_importacoes.mes = df_importacoes.mes.astype('int64')

# %% [markdown]
# def calVIF(X):
#     vif = pd.DataFrame()
#     vif['variables'] = X.columns
#     vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
#
#     return vif
#
# calVIF(df_importacoes.loc[:, df_importacoes.columns != 'valor'])

# %% [markdown]
# plt.figure(figsize=(25, 10))
# sns.heatmap(df_importacoes.loc[:, df_importacoes.columns != 'valor'].corr(), annot=True, fmt='.2f')

# %%
#df_importacoes.info()

# %%
#create tmp train/test split for assumptions test
X = df21.drop(['valor_norm'], axis=1)
y = df21['valor_norm']

X = sm.add_constant(X)
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=50)

model = sm.OLS(y_train, x_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             valor_norm   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                 1.441e+05
# Date:                Sun, 01 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:53:11   Log-Likelihood:             5.9075e+05
# No. Observations:              613484   AIC:                        -1.181e+06
# Df Residuals:                  613479   BIC:                        -1.181e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# quantidade_norm     0.2594      0.000    743.630      0.000       0.259       0.260
# ...

# %%
plt.title('Distribution of Residuals')
sns.distplot(model.resid)
plt.show()

# %%
def normalityError(residuals):
    p_value = normal_ad(residuals)[1]

    print('p-value from the test:', p_value)

    if p_value < 0.05:
        print('Residuals are not normally distributed')
    else:
        print('Residuals are normally distributed')
        
normalityError(model.resid)
# Out:
# p-value from the test: 0.0
# Residuals are not normally distributed

# %%
X = df21.drop(['valor_norm'], axis=1)
y = df21['valor_norm']

X = sm.add_constant(X)
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=50)

# %%
model = sm.OLS(y_train, x_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             valor_norm   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                 1.441e+05
# Date:                Sun, 01 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:53:30   Log-Likelihood:             5.9075e+05
# No. Observations:              613484   AIC:                        -1.181e+06
# Df Residuals:                  613479   BIC:                        -1.181e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# quantidade_norm     0.2594      0.000    743.630      0.000       0.259       0.260
# ...

# %%
y_pred = model.predict(x_test)

# %%
#plot the actual vs predicted values
sns.regplot(y_test, y_pred, line_kws={'color':'red'}, ci=None)

plt.xlabel('Actual')
plt.ylabel('Predictions')
plt.title('Prediction vs Actual')

plt.show()

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# -1.6895189035063893

# %%
print(lr.coef_)
# Out:
# [ 0.00000000e+00  2.37343416e-01  2.37343416e-01  9.68468765e-04
#  -1.90738391e-06  1.62397094e-10 -7.45889166e-05]

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.48087012527677675

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.004626615461812214

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 0.06801922861817983

# %%
X = df_importacoes[['ano','mes','pais']]
Y = df_importacoes['valor_norm']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
print('Linear Regression:')
print()
reg = LinearRegression()
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print('Accuracy:',reg.score(X_train, Y_train)*100)
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
sns.scatterplot(Y_pred, Y_test)
# Out:
# Linear Regression:
#
# Accuracy: 0.22612600651370496
# Mean Absolute Error: 0.0954403545053031
# Mean Squared Error: 0.01380954135232105
# Root Mean Squared Error: 0.1175140049199288
# <AxesSubplot:ylabel='valor_norm'>

# %%
# Random Forest Regressor

print('Random Forest Regressor:')
print()
rfr = RandomForestRegressor()        
rfr.fit(X_train,Y_train)
Y_pred = rfr.predict(X_test)
print('Accuracy:',rfr.score(X_test, Y_test)*100)
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
sns.scatterplot(Y_pred, Y_test)
# Out:
# Random Forest Regressor:
#
# Accuracy: 4.025166172186722
# Mean Absolute Error: 0.09315725709328326
# Mean Squared Error: 0.013275774555651734
# Root Mean Squared Error: 0.11522054745422682
# <AxesSubplot:ylabel='valor_norm'>
